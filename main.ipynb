# %% [markdown]
# ## 1 library

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import matplotlib.pyplot as plt
#from autils import *

# %% [markdown]
# ## 2 load data

# %%
X = np.load("data/X.npy")
y = np.load("data/y.npy")
# lấy 1000 ví dụ đầu để huấn luyện
X = X[0:1000]
y = y[0:1000]

# %% [markdown]
# ### 2.1 xem ví dụ trong data

# %%
print("X[0] = ", X[0])
# Out:
# X[0] =  [ 0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
#   0.00000000e+00  0.00000000e+00  0.00000000e+00  0.00000000e+00
# ...

# %% [markdown]
# ### 2.2 kiểm tra kích thước của tập dữ liệu

# %%
print("Kích thước của X là : " + str(X.shape))
print("kích thước của y là : " + str(y.shape))
# Out:
# Kích thước của X là : (1000, 400)
# kích thước của y là : (1000, 1)

# %% [markdown]
# ### 3 Xây dựng mô hình tensorflow

# %%
model = Sequential([
    tf.keras.Input(shape=(400,)),
    tf.keras.layers.Dense(units=25, activation="sigmoid", name="layer1"),
    tf.keras.layers.Dense(units=15, activation="sigmoid", name="layer2"),
    tf.keras.layers.Dense(units=1, activation="sigmoid", name="layer3")
], name = "my_model"
)

# %%
# tên model số lớp, số lượng tham số cần học, đầu ra mỗi lớp
model.summary()
# Out:
# Model: "my_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  layer1 (Dense)              (None, 25)                10025
#
#  layer2 (Dense)              (None, 15)                390
#
#  layer3 (Dense)              (None, 1)                 16
#
# ...
# Total params: 10431 (40.75 KB)
# Trainable params: 10431 (40.75 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
[layer1, layer2, layer3] = model.layers
print(model.layers[2].weights)
# Out:
# [<tf.Variable 'layer3/kernel:0' shape=(15, 1) dtype=float32, numpy=
# array([[-0.5289682 ],
#        [-0.5746254 ],
#        [ 0.5522923 ],
#        [-0.43594328],
#        [-0.24960545],
#        [ 0.0546791 ],
#        [ 0.3683222 ],
#        [ 0.01197046],
#        [ 0.49212688],
#        [-0.12821293],
#        [ 0.07291758],
#        [ 0.18234736],
#        [ 0.41847926],
#        [-0.15008885],
#        [-0.25466043]], dtype=float32)>, <tf.Variable 'layer3/bias:0' shape=(1,) dtype=float32, numpy=array([0.], dtype=float32)>]

# %% [markdown]
# xác định hàm mất mát và giảm độ dốc cho mô hình với dữ liệu huấn luyện

# %%
model.compile(
    loss=tf.keras.losses.BinaryCrossentropy(),
    optimizer=tf.keras.optimizers.Adam(0.001),
)

model.fit(
    X,y,
    epochs=20
)
# Out:
# Epoch 1/20
# 32/32 [==============================] - 1s 1ms/step - loss: 0.6438
# Epoch 2/20
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4999
# Epoch 3/20
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3644
# Epoch 4/20
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2505
# Epoch 5/20
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1776
# Epoch 6/20
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1332
# Epoch 7/20
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1047
# Epoch 8/20
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0851
# Epoch 9/20
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0710
# Epoch 10/20
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0603
# Epoch 11/20
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0521
# Epoch 12/20
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0457
# ...

# %% [markdown]
# dùng predic để chạy mô hình nhằm đưa ra dự đoán

# %%
prediction = model.predict(X[0].reshape(1,400))  # a zero
print(f" dự đoán 0: {prediction}")
prediction = model.predict(X[500].reshape(1,400))  # a one
print(f" dự đoán 1:  {prediction}")
# Out:
# 1/1 [==============================] - 0s 78ms/step
#  dự đoán 0: [[0.01767294]]
# 1/1 [==============================] - 0s 19ms/step
#  dự đoán 1:  [[0.98428994]]

# %% [markdown]
# dùng ngưỡng để dự đoán đầu ra

# %%
if prediction >= 0.5:
    yhat = 1
else:
    yhat = 0
print(f"prediction after threshold: {yhat}")
# Out:
# prediction after threshold: 1
